# %%
import matplotlib.pyplot as plt

plt.errorbar(
    [1, 2, 4, 6, 8, 10],
    [
        0.9876666561762492,
        0.9948333257436752,
        0.9965666609009107,
        0.9961999946832657,
        0.9971666619181633,
        0.9961999940872193,
    ],
    [
        0.0021449181844307684,
        0.0009169009865212859,
        0.0006893166458647027,
        0.0008221111827205049,
        0.0006693354572385185,
        0.0007628637112054778,
    ],
    label='Protonet',
)
plt.errorbar(
    [1, 2, 4, 6, 8, 10],
    [
        0.979966652393341,
        0.9901666556795438,
        0.9928666594624519,
        0.9936333256959915,
        0.9948999939362208,
        0.9944999933242797,
    ],
    [
        0.0026466040650067724,
        0.0015679440072841949,
        0.001528958726062015,
        0.0013923801410948367,
        0.0014373116009777972,
        0.0012729532256212561,
    ],
    label='MAML',
)
plt.legend()
plt.show()
